# %% [markdown]
# # <center> <font color=gray>Compte Rendu N°3</font></center>
# ### Réaliser par Mohamed amine Sekmani 3DNI2
#
# ## 1/Travail à faire:
# ## <font color=gray> Exercice 1:</font>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# load grav.csv
df = pd.read_csv('Datasets/grav.csv')
df.head()

# Select the first column 
X = df.iloc[0:len(df),0]
# Select the second columns
Y = df.iloc[0:len(df),1] 

axes = plt.axes()
# Draw a grid
axes.grid()  

plt.scatter(X,Y) 
plt.show()

# %%
from scipy import stats

# Linregress returns multiple variables - We are interested in slope and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
def predict(x):
    return slope * x + intercept
# The fitLine variable will be an array of predicted values from the X array
fitLine = predict(X)
plt.plot(X, fitLine, c='r')

# Print 'slope'
print ("slope: ",slope)

# Print 'intercept'
print ("intercept: ",intercept)
# Out:
# slope:  0.10280912511759172
# intercept:  -0.6801232361241745

# %% [markdown]
# ## <font color=gray> Exercice 2:</font>

# %%
# !pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.0.5-cp38-cp38-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 366 kB/s eta 0:00:01
# Requirement already satisfied: pandas>0.24.0 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from pyreadstat) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from pandas>0.24.0->pyreadstat) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from pandas>0.24.0->pyreadstat) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from pandas>0.24.0->pyreadstat) (1.18.5)
# Requirement already satisfied: six>=1.5 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>0.24.0->pyreadstat) (1.15.0)
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.0.5

# %%
import pyreadstat

# load test_score.sav
df, metadata = pyreadstat.read_sav("Datasets/test_scores.sav")
df.head(10)
# Out:
#   school  school_setting  school_type classroom  teaching_method  n_student  \
# 0  ANKYI             1.0          2.0       6OL              0.0       20.0
# 1  ANKYI             1.0          2.0       6OL              0.0       20.0
# 2  ANKYI             1.0          2.0       6OL              0.0       20.0
# 3  ANKYI             1.0          2.0       6OL              0.0       20.0
# 4  ANKYI             1.0          2.0       6OL              0.0       20.0
# 5  ANKYI             1.0          2.0       6OL              0.0       20.0
# 6  ANKYI             1.0          2.0       6OL              0.0       20.0
# 7  ANKYI             1.0          2.0       6OL              0.0       20.0
# 8  ANKYI             1.0          2.0       6OL              0.0       20.0
# 9  ANKYI             1.0          2.0       6OL              0.0       20.0
#
#   student_id  gender  lunch  pretest  posttest
# 0      2FHT3     1.0    2.0     62.0      72.0
# 1      3JIVH     1.0    2.0     66.0      79.0
# 2      3XOWE     0.0    2.0     64.0      76.0
# 3      556O0     1.0    2.0     61.0      77.0
# 4      74LOE     0.0    2.0     64.0      76.0
# 5      7YZO8     1.0    2.0     66.0      74.0
# 6      9KMZD     0.0    2.0     63.0      75.0
# 7      9USQK     1.0    2.0     63.0      72.0
# 8      CS5QP     0.0    2.0     64.0      77.0
# 9      D6HT8     1.0    2.0     61.0      72.0

# %%
# Shape the dataset
df.shape
# Info of dataset
df.info()
# Describe dataset
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           2133 non-null   object
#  1   school_setting   2133 non-null   float64
#  2   school_type      2133 non-null   float64
#  3   classroom        2133 non-null   object
#  4   teaching_method  2133 non-null   float64
#  5   n_student        2133 non-null   float64
#  6   student_id       2133 non-null   object
#  7   gender           2133 non-null   float64
#  8   lunch            2133 non-null   float64
#  9   pretest          2133 non-null   float64
#  10  posttest         2133 non-null   float64
# dtypes: float64(8), object(3)
# memory usage: 183.4+ KB
#        school_setting  school_type  teaching_method    n_student       gender  \
# count     2133.000000  2133.000000      2133.000000  2133.000000  2133.000000
# mean         1.814346     1.258322         0.356306    22.796531     0.495077
# std          0.793525     0.437814         0.479019     4.228893     0.500093
# min          1.000000     1.000000         0.000000    14.000000     0.000000
# 25%          1.000000     1.000000         0.000000    20.000000     0.000000
# 50%          2.000000     1.000000         0.000000    22.000000     0.000000
# 75%          2.000000     2.000000         1.000000    27.000000     1.000000
# max          3.000000     2.000000         1.000000    31.000000     1.000000
#
#              lunch      pretest     posttest
# count  2133.000000  2133.000000  2133.000000
# mean      1.569620    54.955931    67.102203
# std       0.495245    13.563101    13.986789
# min       1.000000    22.000000    32.000000
# 25%       1.000000    44.000000    56.000000
# 50%       2.000000    56.000000    68.000000
# 75%       2.000000    65.000000    77.000000
# max       2.000000    93.000000   100.000000

# %%
# Using pairplot to isualize the data for correlation
sns.pairplot(df, x_vars=['school','school_setting','school_type','classroom','teaching_method','n_student','student_id','gender', 'lunch','pretest'], 
             y_vars='posttest', size=4, aspect=1, kind='scatter')
plt.show()
# Out:
# /home/mohamedamine/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# using heatmap to visualate the data
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
X = df['pretest']
y = df['posttest']
plt.scatter(X,y)
plt.xlabel("pretest")
plt.ylabel("posttest")
# Out:
# Text(0, 0.5, 'posttest')

# %%
# Spletting training and testing variable
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

X_train
y_train
# Out:
# 1455    81.0
# 299     67.0
# 1912    49.0
# 863     92.0
# 298     64.0
#         ...
# 350     57.0
# 1930    53.0
# 79      79.0
# 1859    47.0
# 1544    89.0
# Name: posttest, Length: 1493, dtype: float64

# %%
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train)

# Fitting the resgression line
lr = sm.OLS(y_train, X_train_sm).fit()

print("params:")
lr.params
print("summary:")
lr.summary()
# Out:
# params:
# summary:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               posttest   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                 1.429e+04
# Date:                Sat, 05 Dec 2020   Prob (F-statistic):               0.00
# Time:                        04:44:08   Log-Likelihood:                -4291.4
# No. Observations:                1493   AIC:                             8587.
# Df Residuals:                    1491   BIC:                             8597.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3750      0.465     28.776      0.000      12.463      14.287
# pretest        0.9783      0.008    119.525      0.000       0.962       0.994
# ==============================================================================
# Omnibus:                       20.611   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.131
# Skew:                           0.167   Prob(JB):                     0.000314
# Kurtosis:                       2.616   Cond. No.                         238.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)
plt.plot(X_train, 13.3750 + 0.9783*X_train, 'r')
plt.show()

# %%
# Predicting y_train_pred using traingn data of X
y_train_pred = lr.predict(X_train_sm)
# Creating residuals from the y_train data and predicted y_data
res = (y_train - y_train_pred)

# Plotting the histogram using the residual values
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %%
# Looking for any patterns in the residuals
plt.scatter(X_train,res)
plt.show()

# %%
# Adding a constant to X_test
X_test_sm = sm.add_constant(X_test)
# Predicting the y values corresponding to X_test_sm
y_test_pred = lr.predict(X_test_sm)
# Printing the first 15 predicted values
y_test_pred
# Out:
# 686     58.377169
# 1836    58.377169
# 1587    88.704726
# 63      78.921643
# 1348    71.095177
#           ...
# 146     76.965027
# 374     51.529011
# 1989    75.986718
# 581     53.485628
# 272     64.247019
# Length: 640, dtype: float64

# %%
from sklearn.metrics import r2_score

# Checking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
print("r_squared: ",r_squared)

# Visualize the line on the test set
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()
# Out:
# r_squared:  0.9009451419275621

# %%
# Splitting to train and test variable
from sklearn.model_selection import train_test_split

X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# Shape of the train set without adding column
X_train_lm.shape
# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)
print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (1493, 1)
# (640, 1)

# %%
from sklearn.linear_model import LinearRegression

# Creating an object of Linear Regression
lm = LinearRegression()
# Fit the model using .fit() method
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression()

# %%
#Intercept value
print("Intercept :",lm.intercept_)
# Slope value
print('Slope :',lm.coef_)

# Making Predictions of y_value
y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test_lm)
# Comparing the r2 value of both train and test data
print("y_train,y_train_pred score:",r2_score(y_train,y_train_pred))
print("y_test,y_test_pred score:",r2_score(y_test,y_test_pred))
# Out:
# Intercept : 13.374988195767308
# Slope : [0.97830828]
# y_train,y_train_pred score: 0.9054961340673476
# y_test,y_test_pred score: 0.900945141927562

# %% [markdown]
# ## <font color=gray> Exercice 3:</font>

# %% [markdown]
# Import the data and specify the variable types with the Type node

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

# %%
from sklearn.datasets import load_boston
bh_data = load_boston()
boston_dataset = load_boston()

#print the value of the boston_dataset to see her contains. 
print(bh_data.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston = pd.DataFrame(bh_data.data, columns=boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Add a Regression node to the stream and select MEDV as the target variable and all other variables as the
# input.

# %%
boston['MEDV'] = bh_data.target
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# #### <font color=black> Data preprocessing: </font>

# %%
#See and count the number of missing values for each feature.
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# #### <font color=black> Exploratory Data Analysis: </font>
# understand the relationship of the target variable with other features.

# %%
#understand the relationship of the target variable with other features by plotin 
#the distribution of the target variable MEDV
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['MEDV'], bins=30)
plt.show()

# %% [markdown]
# =>The values of MEDV are distributed normally with few outliers

# %% [markdown]
# Choose the Backwards method to find the significant input variables and then run the stream

# %%
correlation_matrix = boston.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# Inspect the model nugget and identify the estimated coefficients and the regression equation. Which variables are included in the final model, and which variable has a coefficient of 3.832?

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = boston['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %% [markdown]
# =>The prices increase immediattely with the value of RM.
#
# =>The data seems to be capped at 50.
#
# =>The prices decrease with an increase in LSTAT.
#
# =>Not looking to be following exactly a linear line.

# %%
# Preparing the data for training the model
X = pd.DataFrame(np.c_[boston['LSTAT'], boston['RM']], columns = ['LSTAT','RM'])
Y = boston['MEDV']

#Splitting the data into training and testing sets 
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %% [markdown]
# We split the data into training and testing sets. We train the model with 80% of the samples and test with the remaining 20% to assess the model’s performance on unseen data.
# We use train_test_split function provided by scikit-learn library

# %%
pip install watermark
# Out:
# Collecting watermark
#   Downloading watermark-2.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: ipython in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from watermark) (7.16.1)
# Requirement already satisfied: traitlets>=4.2 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (4.3.3)
# Requirement already satisfied: backcall in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (3.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: pickleshare in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.17.1)
# Requirement already satisfied: decorator in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (49.2.0.post20200714)
# Requirement already satisfied: pygments in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (2.6.1)
# Requirement already satisfied: six in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->watermark) (1.15.0)
# Requirement already satisfied: ipython-genutils in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->watermark) (0.2.0)
# Requirement already satisfied: wcwidth in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython->watermark) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/mohamedamine/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython->watermark) (0.7.0)
# Installing collected packages: watermark
# Successfully installed watermark-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Training and testing the model
# %load_ext watermark

# python, ipython, packages, and machine characteristics
# %watermark -v -m -p pandas,numpy,watermark 

# date
print (" ")
# %watermark -u -n -t -z
# Out:
# Python implementation: CPython
# Python version       : 3.8.3
# IPython version      : 7.16.1
#
# pandas   : 1.0.5
# numpy    : 1.18.5
# watermark: 2.1.0
#
# Compiler    : GCC 7.3.0
# OS          : Linux
# Release     : 5.4.0-54-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
#
# Last updated: Sat Dec 05 2020 05:31:55CET

# %% [markdown]
# =>We use scikit-learn’s LinearRegression to train the model on both the training and test sets.
